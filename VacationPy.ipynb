# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests

# Import the API key.
from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID             City Country                 Date      Lat       Lng  \
# 0        0           Knysna      ZA  2022-09-03 02:15:21 -34.0363   23.0471
# 1        1  Bambous Virieux      MU  2022-09-03 02:15:21 -20.3428   57.7575
# 2        2          Rikitea      PF  2022-09-03 02:15:22 -23.1203 -134.9692
# 3        3       Nikolskoye      RU  2022-09-03 02:15:22  59.7035   30.7861
# 4        4        Tilichiki      RU  2022-09-03 02:15:22  60.4667  166.1000
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     53.74        80           0        4.50
# 1     68.25        73          40        8.05
# 2     70.34        68          77       20.65
# 3     44.87        85          90        5.82
# 4     57.36        70          24        6.89

# %%
# Get the data types
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure()
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp,0) for temp in max_temp], dissipating=False, max_intensity=300, point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of cloudiness
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of cloudiness
locations = city_data_df[["Lat", "Lng"]]
wind = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=wind, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID               City Country                 Date      Lat  \
# 15       15             Atuona      PF  2022-09-03 02:15:28  -9.8000
# 16       16              Vaini      TO  2022-09-03 02:15:28 -21.2000
# 19       19                Edd      ER  2022-09-03 02:15:30  13.9297
# 22       22          Alyangula      AU  2022-09-03 02:15:31 -13.8483
# 24       24             Sabang      ID  2022-09-03 02:15:32   5.8933
# 25       25           Havelock      US  2022-09-03 02:15:32  34.8791
# 26       26  Puerto El Triunfo      SV  2022-09-03 02:15:33  13.2833
# 28       28               Hilo      US  2022-09-03 02:14:05  19.7297
# 29       29        Nortelandia      BR  2022-09-03 02:15:34 -14.4547
# 42       42              Kutum      SD  2022-09-03 02:15:38  14.2000
#
#          Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 15 -139.0333     77.31        70          20       23.60
# 16 -175.2000     75.36        78          20       11.50
# 19   41.6925     89.76        64          68        1.05
# 22  136.4192     75.72        68          86       19.01
# 24   95.3214     80.92        77          55       21.99
# 25  -76.9013     82.38        90         100        5.82
# 26  -88.5500     77.83        87          99        1.36
# 28 -155.0900     87.28        75          40        8.05
# 29  -56.8028     82.33        28          63        1.21
# 42   24.6667     77.07        53          49        2.71

# %%
# Determine if there are any null values

preferred_cities_df.count()
# Out:
# City_ID       187
# City          187
# Country       187
# Date          187
# Lat           187
# Lng           187
# Max Temp      187
# Humidity      187
# Cloudiness    187
# Wind Speed    187
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                  City Country  Max Temp      Lat       Lng Hotel Name
# 15             Atuona      PF     77.31  -9.8000 -139.0333
# 16              Vaini      TO     75.36 -21.2000 -175.2000
# 19                Edd      ER     89.76  13.9297   41.6925
# 22          Alyangula      AU     75.72 -13.8483  136.4192
# 24             Sabang      ID     80.92   5.8933   95.3214
# 25           Havelock      US     82.38  34.8791  -76.9013
# 26  Puerto El Triunfo      SV     77.83  13.2833  -88.5500
# 28               Hilo      US     87.28  19.7297 -155.0900
# 29        Nortelandia      BR     82.33 -14.4547  -56.8028
# 42              Kutum      SD     77.07  14.2000   24.6667

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# %%
# Dependencies and Setup
import requests
import gmaps

# Import API key
from config import g_key

# %%
# Set the parameters to search for a hotel in Paris.
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key,
    "location": "48.8566, 2.3522"}

# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")

# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()

hotels
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# {'html_attributions': [],
#  'next_page_token': 'AeJbb3dSjvxkdiXKwyYjeWTNsjUOvPXj0oQujvmjrb2_80MzUU-ORxTYlnv1eBBHQpnSD-8Xpf6l-Ebm7js6qLDQ6cAkmq_YOMDvNwiqx-HVCSfXAXypIj3k2lKUCHNL1QNvqlS5S7TqCJYjR1eZVAudp8XWh5JtUG8o0M_ncsK6esNKFtTv0G_q4wQFCxhsXT3OgxQDPy17LGTftN8AP6fk0o_jAeNJeH2nzXCQ1S_3297D-K4zEbuMv2Egi-lvcrWeJWsgnfLKgPQwBuSwd-PgsDv5OBFFatw-5CvdpkW3kBYprcVl8vySZK1MyeWT3Ez91ggjt1JD1ioqym27zZj9Mq5t_o7CdwAVp5bcFYJWSdOqJRiCLlAJyEfZXhyEXHQvsVek_JQjICQFSfOKDLp2RDZXFDEYMVXXzN24hiojC3lX-G4Cw_94LcQ',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.4172211, 'lng': 31.8126608},
#     'viewport': {'northeast': {'lat': 31.4185035302915,
#       'lng': 31.8140357802915},
#      'southwest': {'lat': 31.4158055697085, 'lng': 31.8113378197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'SULIMAN INN',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112623849447062345898">فندق سليمان ان</a>'],
#      'photo_reference': 'AeJbb3d2dKYVR1tWNy94usSk6D-baRXcMn9IK-_JoLzPNKcpnGweNsndhM5AKUztvykaFfXDBWHkgIe66AKU4pKbj57lYil4f6ACrYmWjU3grgcVkt8YdPmUVlCLUwOBXgh69dujvYe1Y1FV7b4k9C-f8XrZysbPSSF_PMqMZUKUw1SNyQkW',
#      'width': 3024}],
#    'place_id': 'ChIJw4xMcYjv-RQRmaQKJRUj4oM',
#    'plus_code': {'compound_code': 'CR87+V3 Qism Damietta, Damietta Desert, Egypt',
#     'global_code': '8G3HCR87+V3'},
#    'rating': 3.5,
#    'reference': 'ChIJw4xMcYjv-RQRmaQKJRUj4oM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 293,
#    'vicinity': 'El-Galaa, Qism Damietta'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.4176264, 'lng': 31.8142236},
#     'viewport': {'northeast': {'lat': 31.4189680302915,
#       'lng': 31.8155858302915},
#      'southwest': {'lat': 31.4162700697085, 'lng': 31.8128878697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Gallery ahmed abo nasoo',
#    'place_id': 'ChIJvVg2FUPv-RQRRjAReAjijDI',
#    'reference': 'ChIJvVg2FUPv-RQRRjAReAjijDI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'CR97+3M5, ميدان الكباس، قسم دمياط، الظهير الصحراوى لمحافظة دمياط،, Damietta First'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.417873, 'lng': 31.8130749},
#     'viewport': {'northeast': {'lat': 31.4192184302915,
#       'lng': 31.8144001802915},
#      'southwest': {'lat': 31.4165204697085, 'lng': 31.8117022197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'فندق المنشي دمياط',
#    'photos': [{'height': 607,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113655487638512132839">فندق المنشي دمياط</a>'],
#      'photo_reference': 'AeJbb3ff7b2jdwTT3OvFBpdKUkrGjTGE5R144YhCKhXzydRpRXd4aWTr3RkzCqqW-Q2vfhyx5bg3ucPdvQIjrhOVPW556kr1yh0LAg46YZfj7aZ1yiEqMlDz45gSfvBRLVEPqyuxEntBROAB9G8hiOiQnB2hCSQZSNpoBFW92F7efATYnsYN',
#      'width': 1080}],
#    'place_id': 'ChIJRTTsZIjv-RQR53mxSELmpXc',
#    'plus_code': {'compound_code': 'CR97+46 Damietta, Egypt',
#     'global_code': '8G3HCR97+46'},
#    'rating': 3.7,
#    'reference': 'ChIJRTTsZIjv-RQR53mxSELmpXc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 353,
#    'vicinity': 'Qism Damietta, Damietta'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.417539, 'lng': 31.814443},
#     'viewport': {'northeast': {'lat': 31.4189192802915,
#       'lng': 31.8157812302915},
#      'southwest': {'lat': 31.4162213197085, 'lng': 31.8130832697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Alaziz',
#    'place_id': 'ChIJafvVkojv-RQR3N8HlsLl5d4',
#    'plus_code': {'compound_code': 'CR97+2Q Damietta First, Egypt',
#     'global_code': '8G3HCR97+2Q'},
#    'reference': 'ChIJafvVkojv-RQR3N8HlsLl5d4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Street 31، Damietta Desert'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.4175388, 'lng': 31.8144434},
#     'viewport': {'northeast': {'lat': 31.4189192302915,
#       'lng': 31.81578158029149},
#      'southwest': {'lat': 31.4162212697085, 'lng': 31.81308361970849}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'دمياط',
#    'photos': [{'height': 2400,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115510233612645238139">فارس داود</a>'],
#      'photo_reference': 'AeJbb3fc4L6Lf601pSN58QsA22itbzaoezfwhG5miKy8uVY6F-jjsxOUq90kxhd4tIWAd3SLl4grQqCvJMo1qzX-EZyVn3LP9UiVXjKGNbgohwdjb_ku3MGvPEJlKcktCN240J1usou4K-hNy5ic9LtxJkXJkppge3mwNUfVRcPveG9k-vMt',
#      'width': 1080}],
#    'place_id': 'ChIJGU_W73Pv-RQRwyNG-aSG4bM',
#    'reference': 'ChIJGU_W73Pv-RQRwyNG-aSG4bM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'CR97+2Q8'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.4175388, 'lng': 31.8144434},
#     'viewport': {'northeast': {'lat': 31.4189192302915,
#       'lng': 31.81578158029149},
#      'southwest': {'lat': 31.4162212697085, 'lng': 31.81308361970849}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'دقهله',
#    'place_id': 'ChIJg_vVkojv-RQRKbfas4f7-04',
#    'rating': 2.8,
#    'reference': 'ChIJg_vVkojv-RQRKbfas4f7-04',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': 'CR97+2Q8, Qism Damietta, Damietta'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.4176201, 'lng': 31.8144407},
#     'viewport': {'northeast': {'lat': 31.4189325302915,
#       'lng': 31.8158022302915},
#      'southwest': {'lat': 31.4162345697085, 'lng': 31.8131042697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'ArTiSt Gallery',
#    'place_id': 'ChIJeRhtmYnv-RQRMbpiuK1t78k',
#    'reference': 'ChIJeRhtmYnv-RQRMbpiuK1t78k',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'CR97+2QW, El-Galaa, Qism Damietta, Damietta Desert'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.4150253, 'lng': 31.81447019999999},
#     'viewport': {'northeast': {'lat': 31.4163935302915,
#       'lng': 31.8157965802915},
#      'southwest': {'lat': 31.4136955697085, 'lng': 31.8130986197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'فنلندا',
#    'place_id': 'ChIJm6a2stbv-RQROslzBi0KRy0',
#    'reference': 'ChIJm6a2stbv-RQROslzBi0KRy0',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'CR87+2Q9, العراقي، قسم دمياط، الظهير الصحراوى لمحافظة دمياط،, Damietta First'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.41531299999999, 'lng': 31.8105352},
#     'viewport': {'northeast': {'lat': 31.4167065802915,
#       'lng': 31.81185308029151},
#      'southwest': {'lat': 31.4140086197085, 'lng': 31.80915511970851}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'دمياط فندق عماد',
#    'photos': [{'height': 4000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104505754268272475381">Me Do</a>'],
#      'photo_reference': 'AeJbb3eouxsc6vl0BSo89IrCbTTWHFMUTZuybtmqk6-OLRRYdYRyEvIn6oK5cTd_2ExTC1gKFHKW1vAMTM_ghP5GIThYlsbnws9B28007Cp07BK4Ufsxb_EcRgMeaQhgEiBgth1O83KTm_0abYSZJotMfH2bJYHiT4wLP_O6x94vSGzlqDQz',
#      'width': 1800}],
#    'place_id': 'ChIJbXSU0Wjl-RQR3Eua59zkdAo',
#    'rating': 3.2,
#    'reference': 'ChIJbXSU0Wjl-RQR3Eua59zkdAo',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 33,
#    'vicinity': 'CR86+46F, كورنيش النيل, قسم دمياط، دمياط،'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.414369, 'lng': 31.8161826},
#     'viewport': {'northeast': {'lat': 31.4157019802915,
#       'lng': 31.8174952802915},
#      'southwest': {'lat': 31.4130040197085, 'lng': 31.8147973197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'AHMED HAZEM',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 869,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109709996396148573050">Raed Elmanzalawy</a>'],
#      'photo_reference': 'AeJbb3c8GbeTSNWudmJEaXJBLOORMbRwIktlZKY8aABCGvWbsYihMxrN-6OehzP950x9ST-I-IUPTxGDDtHtRDLeq79wXZ4Mw-NoRyC3bQBY-yE_UCD6Uco7qjNyD0z4wot2eq4xEzlQYhjwGAL77R3Bpy9gE2yOeS6U9QkHmGllLE6Ib2Jz',
#      'width': 720}],
#    'place_id': 'ChIJvZj0DiHv-RQR8640uLdusnM',
#    'rating': 4,
#    'reference': 'ChIJvZj0DiHv-RQR8640uLdusnM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': 'CR78+PFV, Unnamed Road, قسم دمياط،, Damietta First'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.417713, 'lng': 31.8172658},
#     'viewport': {'northeast': {'lat': 31.4190465802915,
#       'lng': 31.8186141802915},
#      'southwest': {'lat': 31.4163486197085, 'lng': 31.8159162197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': "Abdelbaky's",
#    'photos': [{'height': 1982,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113188523598080146344">Shaza Abdelbaky</a>'],
#      'photo_reference': 'AeJbb3c5YWVFKCirRK3M9ByYuenkmkje_933iJpy3PAAx5VqpLd2lGRICieBEaq5LHPQiSB0YSGGdlWb-gGtdXafBQu5Bl_0HNQ57NOR5b6tGc7yMo4bvi2gf2al2topANnC2zTrabqNZQ08kFtcw3Z9waGJF6uwWAU_LtRzRp2bXa830IjP',
#      'width': 2643}],
#    'place_id': 'ChIJgUZmEw3v-RQR_C0YZBP5MSw',
#    'rating': 5,
#    'reference': 'ChIJgUZmEw3v-RQR_C0YZBP5MSw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'CR98+3WJ, El-Galaa, Qism Damietta, Damietta Desert'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.4191747, 'lng': 31.8164286},
#     'viewport': {'northeast': {'lat': 31.4205271302915,
#       'lng': 31.8177203302915},
#      'southwest': {'lat': 31.4178291697085, 'lng': 31.8150223697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'كنوز الفيروز',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJD5yagIzv-RQRokfxfxzH5cU',
#    'reference': 'ChIJD5yagIzv-RQRokfxfxzH5cU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'CR98+MH7, اول دمياط،, Damietta First'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.4202999, 'lng': 31.8137597},
#     'viewport': {'northeast': {'lat': 31.4216240302915,
#       'lng': 31.81509348029149},
#      'southwest': {'lat': 31.4189260697085, 'lng': 31.8123955197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'الحاج مسعد الموافي',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1280,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111514461556395830160">All- One</a>'],
#      'photo_reference': 'AeJbb3e_gm3jPpoISSXk1aSACAW7WjieJOLYdU8HfpBDzTqYHsJg6FTxT9cBwJckUmF1kySDOCfLOg1z4i4Q7vTlYcPwiUV_tXAq0uWpK2O1Jt77eVb8sl5S1eFig-xZgTP0ZSDyR0pzKPA9nKAU0AiLciFuxNylETLKRSahRq8HRDTNpp6c',
#      'width': 720}],
#    'place_id': 'ChIJrawU-qfv-RQR6yK-oAycBMY',
#    'rating': 5,
#    'reference': 'ChIJrawU-qfv-RQR6yK-oAycBMY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'CRC7+4G6, دمياط، قسم دمياط، الظهير الصحراوى لمحافظة دمياط،, Damietta First'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.4203266, 'lng': 31.813961},
#     'viewport': {'northeast': {'lat': 31.42167643029149,
#       'lng': 31.8153104302915},
#      'southwest': {'lat': 31.4189784697085, 'lng': 31.8126124697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'مكتب المستشار مدحت البنا',
#    'place_id': 'ChIJuaD7fdfv-RQRZFPimKC3QVg',
#    'reference': 'ChIJuaD7fdfv-RQRZFPimKC3QVg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'اعلي قهوة ابو مهدي, القديمة'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.4140343, 'lng': 31.81721990000001},
#     'viewport': {'northeast': {'lat': 31.4153720802915,
#       'lng': 31.8185901302915},
#      'southwest': {'lat': 31.4126741197085, 'lng': 31.8158921697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'اليوم',
#    'place_id': 'ChIJtwxBcfnv-RQR9ev6oUMSybs',
#    'reference': 'ChIJtwxBcfnv-RQR9ev6oUMSybs',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'CR78+JV9, باب الحرس، قسم دمياط، الظهير الصحراوى لمحافظة دمياط، دمياط،, Damietta'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.42064019999999, 'lng': 31.8132315},
#     'viewport': {'northeast': {'lat': 31.4220221302915,
#       'lng': 31.81459693029149},
#      'southwest': {'lat': 31.4193241697085, 'lng': 31.81189896970849}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'السيد السيد بدر للكراسي',
#    'place_id': 'ChIJgTO-ob_v-RQRvPpgR4xLTWs',
#    'reference': 'ChIJgTO-ob_v-RQRvPpgR4xLTWs',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'CRC7+775, Fekry Zaher, Qism Damietta, Damietta Desert'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.41243, 'lng': 31.81488330000001},
#     'viewport': {'northeast': {'lat': 31.41375148029149,
#       'lng': 31.8162690802915},
#      'southwest': {'lat': 31.4110535197085, 'lng': 31.8135711197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'منزل الحاج سلامة حمود',
#    'place_id': 'ChIJM00SBuHv-RQREMhPVyLPHmA',
#    'reference': 'ChIJM00SBuHv-RQREMhPVyLPHmA',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'CR67+XXC, الترعة الرئيسية، قسم دمياط، دمياط،, Damietta First'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.4124147, 'lng': 31.8149224},
#     'viewport': {'northeast': {'lat': 31.41375263029149,
#       'lng': 31.8162862302915},
#      'southwest': {'lat': 31.4110546697085, 'lng': 31.8135882697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'أستاذ محمد حمود',
#    'place_id': 'ChIJZSyhi9bv-RQRQMgiLw2_460',
#    'rating': 4,
#    'reference': 'ChIJZSyhi9bv-RQRQMgiLw2_460',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'CR67+XX7, دمياط، قسم دمياط،، دمياط،, Damietta First'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.4117516, 'lng': 31.8139365},
#     'viewport': {'northeast': {'lat': 31.4131022802915,
#       'lng': 31.81524268029149},
#      'southwest': {'lat': 31.4104043197085, 'lng': 31.8125447197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'مالك تاور شركه مالك للتطوير العقاري',
#    'photos': [{'height': 3334,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118190072950657717497">مالك للتطويرالعقاري وإدارة المشروعات</a>'],
#      'photo_reference': 'AeJbb3dPYXCuWwSmLkdsKNbE0rwcIynq7XfXvkQNUR_DjFPqVK65qTzawVyWF3BzjOgeu_qKZ39n2d6DiR3hpBDihZ9lmKhvNgU4YR2RhJP74dVTcphj5FR145aSa-ni-I8g42j1E2G1tKYFwCeUAl96T2KyCcNdUDlSXS4LR7ZoXtBi7Fuw',
#      'width': 3334}],
#    'place_id': 'ChIJIVotehrv-RQRseLvV_j1UFw',
#    'reference': 'ChIJIVotehrv-RQRseLvV_j1UFw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'CR67+PH3, ميدان سرور، قسم دمياط، اول دمياط،, Damietta First'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.4112694, 'lng': 31.81552619999999},
#     'viewport': {'northeast': {'lat': 31.4126501302915,
#       'lng': 31.8168935302915},
#      'southwest': {'lat': 31.4099521697085, 'lng': 31.8141955697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'كاوتشوك صبحي',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJLQY0yVvv-RQRPGL5_8yqe1w',
#    'reference': 'ChIJLQY0yVvv-RQRPGL5_8yqe1w',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'CR68+G62, باب الحرس، قسم دمياط، دمياط،، قسم دمياط، دمياط،, Damietta'}],
#  'status': 'OK'}

# %%
len(hotels["results"])
# Out:
# 20
